# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

def plot(file_path):
    data = pd.read_csv(file_path)
    
    plt.figure(figsize = (6,6))
    sns.scatterplot(data = data , 
                    x = "x" , 
                    y = "y" , 
                    hue = "group",
                    hue_order = ['A' , 'B' , 'C'],
                    palette = 'muted')
    plt.title("Spatial Distributions of Groups")
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.legend(title = "Group")
    plt.show()

# %% [markdown]
# ## Case1

# %% [markdown]
# ### Truth image

# %%
plot("data/simulate/Case1 (center_edge)/center_edge(0331)/truth_SpatialData.csv")

# %% [markdown]
# ### edge error

# %%
plot("data/simulate/Case1 (center_edge)/center_edge(0331)/edge_SpatialData.csv")

# %% [markdown]
# ### center error

# %%
plot("data/simulate/Case1 (center_edge)/center_edge(0331)/center_SpatialData.csv")

# %% [markdown]
# ## Case2.1

# %%
plot("data/simulate/Case2.1/truth_SpatialData.csv")

# %%
plot("data/simulate/Case2.1/N-A_SpatialData.csv")

# %%
plot("data/simulate/Case2.1/A-N_SpatialData.csv")

# %% [markdown]
# ## Case2.2

# %%
plot("data/simulate/Case2.2/Truth_SpatialData.csv")

# %%
plot("data/simulate/Case2.2/BA_SpatialData.csv")

# %%
plot("data/simulate/Case2.2/CA_SpatialData.csv")

# %% [markdown]
# ## Case4

# %% [markdown]
# ### case4.1：不同的类分到一类

# %%
plot(r"data/simulate/Case4 (GeneSimilarity)/4.1/4.1(0331)/sim_truth_SpatialData.csv")

# %%
plot(r"data/simulate/Case4 (GeneSimilarity)/4.1/4.1(0331)/sim_pred_SpatialData.csv")

# %%
plot(r"data/simulate/Case4 (GeneSimilarity)/4.1/4.1(0331)/dissim_truth_SpatialData.csv")

# %%
plot(r"data/simulate/Case4 (GeneSimilarity)/4.1/4.1(0331)/dissim_pred_SpatialData.csv")

# %% [markdown]
# ### Case4.2:同一类到不同类

# %%
plot(r"C:\CodeFields\Spatial Group Discrepancy\Code\data\simulate\Case4\4.2\sim_truth_SpatialData.csv")

# %%
plot(r"C:\CodeFields\Spatial Group Discrepancy\Code\data\simulate\Case4\4.2\dissim_truth_SpatialData.csv")

# %%
plot(r"C:\CodeFields\Spatial Group Discrepancy\Code\data\simulate\Case4\4.2\sim_pred_SpatialData.csv")

# %%
plot(r"C:\CodeFields\Spatial Group Discrepancy\Code\data\simulate\Case4\4.2\dissim_pred_SpatialData.csv")
